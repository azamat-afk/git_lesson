# %%
import pandas as pd
a=pd.read_excel('C:/Users\Azamat/Downloads/H-1B_Disclosure_Data_FY2019.xlsx', index_col=0)

# %%
a.columns
# Out:
# Index(['CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE', 'ORIGINAL_CERT_DATE',
#        'VISA_CLASS', 'EMPLOYMENT_START_DATE', 'EMPLOYMENT_END_DATE',
#        'EMPLOYER_NAME', 'EMPLOYER_BUSINESS_DBA', 'EMPLOYER_ADDRESS',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE',
#        'EMPLOYER_PHONE_EXT', 'SECONDARY_ENTITY',
#        'SECONDARY_ENTITY_BUSINESS_NAME', 'AGENT_REPRESENTING_EMPLOYER',
#        'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_STATE',
#        'JOB_TITLE', 'SOC_CODE', 'SOC_NAME', 'NAICS_CODE', 'TOTAL_WORKERS',
#        'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT', 'CHANGE_PREVIOUS_EMPLOYMENT',
#        'NEW_CONCURRENT_EMPLOYMENT', 'CHANGE_EMPLOYER', 'AMENDED_PETITION',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_LEVEL', 'PW_SOURCE', 'PW_SOURCE_OTHER',
# ...

# %%
a[a['EMPLOYER_CITY'] == 'CHATTANOOGA']
# Out:
#                    CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# CASE_NUMBER
# I-200-19184-057322   CERTIFIED     2019-07-03    2019-07-10
# I-200-19079-090205   CERTIFIED     2019-03-20    2019-03-26
# I-200-19087-763160   CERTIFIED     2019-03-28    2019-04-03
# I-200-19121-995216   CERTIFIED     2019-05-01    2019-05-07
# I-200-18346-206757   CERTIFIED     2018-12-12    2018-12-18
# ...                        ...            ...           ...
# I-200-19051-387719   CERTIFIED     2019-02-20    2019-02-26
# I-200-19043-498605   CERTIFIED     2019-02-12    2019-02-19
# I-200-19225-009362   CERTIFIED     2019-08-20    2019-08-26
# I-200-18284-964901   CERTIFIED     2018-10-12    2018-10-18
# I-200-19171-013054   CERTIFIED     2019-06-24    2019-06-28
#
#                    ORIGINAL_CERT_DATE VISA_CLASS EMPLOYMENT_START_DATE  \
# CASE_NUMBER
# I-200-19184-057322                NaT       H-1B            2019-07-03
# I-200-19079-090205                NaT       H-1B            2019-08-26
# ...

# %%
a.iloc[1:200, :]
# Out:
#                    CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# CASE_NUMBER
# I-200-18323-885516      DENIED     2018-11-19    2018-11-26
# I-200-18323-882044      DENIED     2018-11-19    2018-11-26
# I-200-18356-858057      DENIED     2018-12-22    2018-12-27
# I-200-19081-827349   CERTIFIED     2019-03-22    2019-03-28
# I-203-19066-246476      DENIED     2019-03-07    2019-03-14
# ...                        ...            ...           ...
# I-200-19083-406699   CERTIFIED     2019-03-24    2019-03-28
# I-200-18272-036492   CERTIFIED     2018-09-29    2018-10-04
# I-200-19009-496121   CERTIFIED     2019-01-17    2019-01-24
# I-200-19029-001220   CERTIFIED     2019-01-29    2019-02-04
# I-200-19029-197661   CERTIFIED     2019-01-29    2019-02-04
#
#                    ORIGINAL_CERT_DATE      VISA_CLASS EMPLOYMENT_START_DATE  \
# CASE_NUMBER
# I-200-18323-885516                NaT            H-1B            2018-11-27
# ...
